# %%
print(utils_dir)
# Out:
# /home/halsali/Desktop/Model_Discovery/GITHUB_REPO/Utils

# %%
import numpy as np
import argparse
import os 
import sys

import matplotlib.pyplot as plt

if "__file__" in globals():
    script_dir = os.path.dirname(os.path.abspath(__file__))
else:
    script_dir = os.getcwd()

utils_dir = os.path.abspath(os.path.join(script_dir, "..", "..", "..", "Utils"))
output_dir = os.path.abspath(os.path.join(script_dir, "..", "Outputs", "Step00", "datasets"))

sys.path.append(utils_dir)
from yaml_processor import load_config, save_config

config_file = os.path.abspath(os.path.join(script_dir, "..", "configuration.yaml"))
config_global = load_config(config_file)

# %%
print(config_global)
# Out:
# {'data': {'param_bounds': {'tau': None, 's': None}, 'n_clusters': 1, 'cluster_bounds': None}, 'model': None, 'training': None}
